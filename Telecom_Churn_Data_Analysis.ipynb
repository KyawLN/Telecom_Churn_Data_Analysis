# %% [markdown]
# # **Telecom Churn Data Analysis**

# %% [markdown]
# ## 1. Importing the initial dataset

# %%
import pandas as pd

df = pd.read_csv('C:/Users/User/Documents/MyUL/CS6471_AR_ML_For_Business/telecom_customer_churn.csv')
print(df)
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0     0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1     0003-MKNFE    Male   46      No                     0      Glendale
# 2     0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0      Martinez
# 4     0013-EXCHZ  Female   75     Yes                     0     Camarillo
# ...          ...     ...  ...     ...                   ...           ...
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# 0        93225  34.827662 -118.999073                    2  ...
# 1        91206  34.162515 -118.203869                    0  ...
# 2        92627  33.645672 -117.922613                    0  ...
# 3        94553  38.014457 -122.115432                    1  ...
# 4        93010  34.227846 -119.079903                    3  ...
# ...        ...        ...         ...                  ...  ...
# 7038     91941  32.759327 -116.997260                    0  ...
# 7039     95367  37.734971 -120.954271                    1  ...
# 7040     95432  39.108252 -123.645121                    0  ...
# 7041     92075  33.001813 -117.263628                    5  ...
# 7042     96125  39.600599 -120.636358                    1  ...
#
#        Payment Method Monthly Charge Total Charges  Total Refunds  \
# 0         Credit Card          65.60        593.30           0.00
# 1         Credit Card          -4.00        542.40          38.33
# 2     Bank Withdrawal          73.90        280.85           0.00
# 3     Bank Withdrawal          98.00       1237.85           0.00
# 4         Credit Card          83.90        267.40           0.00
# ...               ...            ...           ...            ...
# 7038      Credit Card          55.15        742.90           0.00
# 7039  Bank Withdrawal          85.10       1873.70           0.00
# 7040      Credit Card          50.30         92.75           0.00
# 7041      Credit Card          67.85       4627.65           0.00
# 7042  Bank Withdrawal          59.00       3707.60           0.00
#
#      Total Extra Data Charges Total Long Distance Charges Total Revenue  \
# 0                           0                      381.51        974.81
# 1                          10                       96.21        610.28
# 2                           0                      134.60        415.45
# 3                           0                      361.66       1599.51
# 4                           0                       22.14        289.54
# ...                       ...                         ...           ...
# 7038                        0                      606.84       1349.74
# 7039                        0                      356.40       2230.10
# 7040                        0                       37.24        129.99
# 7041                        0                      142.04       4769.69
# 7042                        0                        0.00       3707.60
#
#       Customer Status   Churn Category                   Churn Reason
# 0              Stayed              NaN                            NaN
# 1              Stayed              NaN                            NaN
# 2             Churned       Competitor  Competitor had better devices
# 3             Churned  Dissatisfaction        Product dissatisfaction
# 4             Churned  Dissatisfaction            Network reliability
# ...               ...              ...                            ...
# 7038           Stayed              NaN                            NaN
# 7039          Churned  Dissatisfaction        Product dissatisfaction
# 7040           Joined              NaN                            NaN
# 7041           Stayed              NaN                            NaN
# 7042           Stayed              NaN                            NaN
#
# [7043 rows x 38 columns]

# %% [markdown]
# ## 2. Exporatory Data Analysis & Preview Dataset

# %% [markdown]
# ### 2.1. Data Loading & Initial Inspection

# %%
df.dtypes
# Out:
# Customer ID                           object
# Gender                                object
# Age                                    int64
# Married                               object
# Number of Dependents                   int64
# City                                  object
# Zip Code                               int64
# Latitude                             float64
# Longitude                            float64
# Number of Referrals                    int64
# Tenure in Months                       int64
# Offer                                 object
# Phone Service                         object
# Avg Monthly Long Distance Charges    float64
# Multiple Lines                        object
# Internet Service                      object
# Internet Type                         object
# Avg Monthly GB Download              float64
# Online Security                       object
# Online Backup                         object
# Device Protection Plan                object
# Premium Tech Support                  object
# Streaming TV                          object
# Streaming Movies                      object
# Streaming Music                       object
# Unlimited Data                        object
# Contract                              object
# Paperless Billing                     object
# Payment Method                        object
# Monthly Charge                       float64
# Total Charges                        float64
# Total Refunds                        float64
# Total Extra Data Charges               int64
# Total Long Distance Charges          float64
# Total Revenue                        float64
# Customer Status                       object
# Churn Category                        object
# Churn Reason                          object
# dtype: object

# %%
df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...      Credit Card
# 1     91206  34.162515 -118.203869                    0  ...      Credit Card
# 2     92627  33.645672 -117.922613                    0  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432                    1  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903                    3  ...      Credit Card
#
#   Monthly Charge Total Charges  Total Refunds Total Extra Data Charges  \
# 0           65.6        593.30           0.00                        0
# 1           -4.0        542.40          38.33                       10
# 2           73.9        280.85           0.00                        0
# 3           98.0       1237.85           0.00                        0
# 4           83.9        267.40           0.00                        0
#
#   Total Long Distance Charges Total Revenue  Customer Status   Churn Category  \
# 0                      381.51        974.81           Stayed              NaN
# 1                       96.21        610.28           Stayed              NaN
# 2                      134.60        415.45          Churned       Competitor
# 3                      361.66       1599.51          Churned  Dissatisfaction
# 4                       22.14        289.54          Churned  Dissatisfaction
#
#                     Churn Reason
# 0                            NaN
# 1                            NaN
# 2  Competitor had better devices
# 3        Product dissatisfaction
# 4            Network reliability
#
# [5 rows x 38 columns]

# %%
df.tail()
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# 7038     91941  32.759327 -116.997260                    0  ...
# 7039     95367  37.734971 -120.954271                    1  ...
# 7040     95432  39.108252 -123.645121                    0  ...
# 7041     92075  33.001813 -117.263628                    5  ...
# 7042     96125  39.600599 -120.636358                    1  ...
#
#        Payment Method Monthly Charge Total Charges  Total Refunds  \
# 7038      Credit Card          55.15        742.90            0.0
# 7039  Bank Withdrawal          85.10       1873.70            0.0
# 7040      Credit Card          50.30         92.75            0.0
# 7041      Credit Card          67.85       4627.65            0.0
# 7042  Bank Withdrawal          59.00       3707.60            0.0
#
#      Total Extra Data Charges Total Long Distance Charges Total Revenue  \
# 7038                        0                      606.84       1349.74
# 7039                        0                      356.40       2230.10
# 7040                        0                       37.24        129.99
# 7041                        0                      142.04       4769.69
# 7042                        0                        0.00       3707.60
#
#       Customer Status   Churn Category             Churn Reason
# 7038           Stayed              NaN                      NaN
# 7039          Churned  Dissatisfaction  Product dissatisfaction
# 7040           Joined              NaN                      NaN
# 7041           Stayed              NaN                      NaN
# 7042           Stayed              NaN                      NaN
#
# [5 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Married', 'Number of Dependents',
#        'City', 'Zip Code', 'Latitude', 'Longitude', 'Number of Referrals',
#        'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Customer Status', 'Churn Category', 'Churn Reason'],
#       dtype='object')

# %%
df.shape
# Out:
# (7043, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   City                               7043 non-null   object
#  6   Zip Code                           7043 non-null   int64
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Number of Referrals                7043 non-null   int64
#  10  Tenure in Months                   7043 non-null   int64
#  11  Offer                              3166 non-null   object
#  12  Phone Service                      7043 non-null   object
#  13  Avg Monthly Long Distance Charges  6361 non-null   float64
#  14  Multiple Lines                     6361 non-null   object
#  15  Internet Service                   7043 non-null   object
#  16  Internet Type                      5517 non-null   object
#  17  Avg Monthly GB Download            5517 non-null   float64
#  18  Online Security                    5517 non-null   object
#  19  Online Backup                      5517 non-null   object
#  20  Device Protection Plan             5517 non-null   object
#  21  Premium Tech Support               5517 non-null   object
#  22  Streaming TV                       5517 non-null   object
#  23  Streaming Movies                   5517 non-null   object
#  24  Streaming Music                    5517 non-null   object
#  25  Unlimited Data                     5517 non-null   object
#  26  Contract                           7043 non-null   object
#  27  Paperless Billing                  7043 non-null   object
#  28  Payment Method                     7043 non-null   object
#  29  Monthly Charge                     7043 non-null   float64
#  30  Total Charges                      7043 non-null   float64
#  31  Total Refunds                      7043 non-null   float64
#  32  Total Extra Data Charges           7043 non-null   int64
#  33  Total Long Distance Charges        7043 non-null   float64
#  34  Total Revenue                      7043 non-null   float64
#  35  Customer Status                    7043 non-null   object
#  36  Churn Category                     1869 non-null   object
#  37  Churn Reason                       1869 non-null   object
# dtypes: float64(9), int64(6), object(23)
# memory usage: 2.0+ MB

# %% [markdown]
# ### 2.2. Data Quality & Missing Value Analysis

# %%
df.describe()
# Out:
#                Age  Number of Dependents      Zip Code     Latitude  \
# count  7043.000000           7043.000000   7043.000000  7043.000000
# mean     46.509726              0.468692  93486.070567    36.197455
# std      16.750352              0.962802   1856.767505     2.468929
# min      19.000000              0.000000  90001.000000    32.555828
# 25%      32.000000              0.000000  92101.000000    33.990646
# 50%      46.000000              0.000000  93518.000000    36.205465
# 75%      60.000000              0.000000  95329.000000    38.161321
# max      80.000000              9.000000  96150.000000    41.962127
#
#          Longitude  Number of Referrals  Tenure in Months  \
# count  7043.000000          7043.000000       7043.000000
# mean   -119.756684             1.951867         32.386767
# std       2.154425             3.001199         24.542061
# min    -124.301372             0.000000          1.000000
# 25%    -121.788090             0.000000          9.000000
# 50%    -119.595293             0.000000         29.000000
# 75%    -117.969795             3.000000         55.000000
# max    -114.192901            11.000000         72.000000
#
#        Avg Monthly Long Distance Charges  Avg Monthly GB Download  \
# count                        6361.000000              5517.000000
# mean                           25.420517                26.189958
# std                            14.200374                19.586585
# min                             1.010000                 2.000000
# 25%                            13.050000                13.000000
# 50%                            25.690000                21.000000
# 75%                            37.680000                30.000000
# max                            49.990000                85.000000
#
#        Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# count     7043.000000    7043.000000    7043.000000               7043.000000
# mean        63.596131    2280.381264       1.962182                  6.860713
# std         31.204743    2266.220462       7.902614                 25.104978
# min        -10.000000      18.800000       0.000000                  0.000000
# 25%         30.400000     400.150000       0.000000                  0.000000
# 50%         70.050000    1394.550000       0.000000                  0.000000
# 75%         89.750000    3786.600000       0.000000                  0.000000
# max        118.750000    8684.800000      49.790000                150.000000
#
#        Total Long Distance Charges  Total Revenue
# count                  7043.000000    7043.000000
# mean                    749.099262    3034.379056
# std                     846.660055    2865.204542
# min                       0.000000      21.360000
# 25%                      70.545000     605.610000
# 50%                     401.440000    2108.640000
# 75%                    1191.100000    4801.145000
# max                    3564.720000   11979.340000

# %%
# Checking Null value in each columns

df.isnull().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# Streaming TV                         1526
# Streaming Movies                     1526
# Streaming Music                      1526
# Unlimited Data                       1526
# Contract                                0
# Paperless Billing                       0
# Payment Method                          0
# Monthly Charge                          0
# Total Charges                           0
# Total Refunds                           0
# Total Extra Data Charges                0
# Total Long Distance Charges             0
# Total Revenue                           0
# Customer Status                         0
# Churn Category                       5174
# Churn Reason                         5174
# dtype: int64

# %%
# Checking total numbers of Null value in dataset

df.isnull().sum().sum()
# Out:
# np.int64(30849)

# %%
# Checking tatal numbers of blanks valuse in dataset

(df == '').sum()
# Out:
# Customer ID                          0
# Gender                               0
# Age                                  0
# Married                              0
# Number of Dependents                 0
# City                                 0
# Zip Code                             0
# Latitude                             0
# Longitude                            0
# Number of Referrals                  0
# Tenure in Months                     0
# Offer                                0
# Phone Service                        0
# Avg Monthly Long Distance Charges    0
# Multiple Lines                       0
# Internet Service                     0
# Internet Type                        0
# Avg Monthly GB Download              0
# Online Security                      0
# Online Backup                        0
# Device Protection Plan               0
# Premium Tech Support                 0
# Streaming TV                         0
# Streaming Movies                     0
# Streaming Music                      0
# Unlimited Data                       0
# Contract                             0
# Paperless Billing                    0
# Payment Method                       0
# Monthly Charge                       0
# Total Charges                        0
# Total Refunds                        0
# Total Extra Data Charges             0
# Total Long Distance Charges          0
# Total Revenue                        0
# Customer Status                      0
# Churn Category                       0
# Churn Reason                         0
# dtype: int64

# %%
# Checking both Null & Blank values in dataset

df.replace('', pd.NA).isna().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# Streaming TV                         1526
# Streaming Movies                     1526
# Streaming Music                      1526
# Unlimited Data                       1526
# Contract                                0
# Paperless Billing                       0
# Payment Method                          0
# Monthly Charge                          0
# Total Charges                           0
# Total Refunds                           0
# Total Extra Data Charges                0
# Total Long Distance Charges             0
# Total Revenue                           0
# Customer Status                         0
# Churn Category                       5174
# Churn Reason                         5174
# dtype: int64

# %%
# Checking total duplicate rows in dataset

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Diplay all duplicate rows in dataset

df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Gender, Age, Married, Number of Dependents, City, Zip Code, Latitude, Longitude, Number of Referrals, Tenure in Months, Offer, Phone Service, Avg Monthly Long Distance Charges, Multiple Lines, Internet Service, Internet Type, Avg Monthly GB Download, Online Security, Online Backup, Device Protection Plan, Premium Tech Support, Streaming TV, Streaming Movies, Streaming Music, Unlimited Data, Contract, Paperless Billing, Payment Method, Monthly Charge, Total Charges, Total Refunds, Total Extra Data Charges, Total Long Distance Charges, Total Revenue, Customer Status, Churn Category, Churn Reason]
# Index: []
#
# [0 rows x 38 columns]

# %%
# Missing data visual overview

# !pip install missingno
import missingno as msno

msno.matrix(df)
# Out:
# Requirement already satisfied: missingno in c:\users\user\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from missingno) (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from missingno) (3.10.0)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from missingno) (1.15.3)
# Requirement already satisfied: seaborn in c:\users\user\anaconda3\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\anaconda3\lib\site-packages (from seaborn->missingno) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# <Axes: >

# %% [markdown]
# ### 2.3. Churn Analysis & Visualization

# %%
import matplotlib.pyplot as plt

# %%
df[['Total Revenue', 'Customer Status', 'Churn Category']].head()
# Out:
#    Total Revenue Customer Status   Churn Category
# 0         974.81          Stayed              NaN
# 1         610.28          Stayed              NaN
# 2         415.45         Churned       Competitor
# 3        1599.51         Churned  Dissatisfaction
# 4         289.54         Churned  Dissatisfaction

# %%
churned_df = df[df['Customer Status'] == 'Churned']

# %%
churn_summary = churned_df.groupby('Churn Category', dropna=False)['Total Revenue'].sum().reset_index()

# %%
total_revenue = churn_summary['Total Revenue'].sum()
churn_summary['%'] = (churn_summary['Total Revenue'] / total_revenue * 100).round(2)

# %%
grand_total = pd.DataFrame({
    'Churn Category': ['Grand Total'],
    'Total Revenue': [total_revenue],
    '%': ['']
})

# %%
churn_table = pd.concat([churn_summary, grand_total], ignore_index=True)

# %%
churn_table['Total Revenue'] = churn_table['Total Revenue'].apply(lambda x: f"{x:,.2f}" if isinstance(x, (int, float)) else x)
churn_table['%'] = churn_table['%'].apply(lambda x: f"{x}%" if isinstance(x, (int, float)) else x)

# %%
print(churn_table)
# Out:
#     Churn Category Total Revenue       %
# 0         Attitude    579,554.13  15.73%
# 1       Competitor  1,694,413.15  45.99%
# 2  Dissatisfaction    617,979.26  16.77%
# 3            Other    354,389.14   9.62%
# 4            Price    438,124.14  11.89%
# 5      Grand Total  3,684,459.82

# %%
import seaborn as sns

# %%
data = {
    'Churn Category': ['Attitude', 'Competitor', 'Dissatisfaction', 'Other', 'Price'],
    'Churn_Revenue': [579554.13, 1694413.15, 617979.26, 354389.14, 438124.14],
    '%': [15.73, 45.99, 16.77, 9.62, 11.89]}

# %%
churn_table = pd.DataFrame(data)

# %%
plt.figure(figsize=(8,8))
plt.pie(churn_table['Churn_Revenue'], 
        labels=churn_table['Churn Category'], 
        autopct='%1.1f%%', 
        startangle=140,
        colors=plt.cm.tab20.colors)  
plt.title("Churn Revenue")
plt.axis('equal')
plt.show()

# %% [markdown]
# *Insight	Observation	Business Implication
# Dominant churn driver	Competitor (46%)	Need for competitive strategy improvement
# Internal issues	Dissatisfaction + Attitude (32%)	Focus on quality and service experience
# Financial impact	$1.7M lost to competitors	High priority retention focus area
# Improvement potential	Pricing & Other (22%)	Opportunity to reduce churn by value re-alignment*

# %% [markdown]
# ### 2.4. Correlation Matrix (Heatmap) - Churn Likelihood Drivers

# %%
# Select Key Numerical Columns for Churn Analysis

num_cols = [
    'Tenure in Months',
    'Monthly Charge',
    'Total Charges',
    'Total Revenue',
    'Total Refunds',
    'Total Long Distance Charges',
    'Number of Referrals'
]

# %%
# Convert 'Customer Status' (Stayed, Churned, Joined) to numeric flag

df['Churn_Flag'] = df['Customer Status'].map({'Churned': 1, 'Stayed': 0, 'Joined': 0})

# %%
# Keep only selected numerical columns + churn flag

corr_df = df[num_cols + ['Churn_Flag']].copy()

# %%
# Handle missing or non-numeric values

corr_df = corr_df.apply(pd.to_numeric, errors='coerce').dropna()

# %%
# Compute Correlation Matrix

corr_matrix = corr_df.corr()

# %%
# Display Correlation Values Sorted by Churn Flag

print("\nCorrelation of features with Churn_Flag:\n")
print(corr_matrix['Churn_Flag'].sort_values(ascending=False))
# Out:
# Correlation of features with Churn_Flag:
#
# Churn_Flag                     1.000000
# Monthly Charge                 0.187833
# Total Refunds                 -0.033709
# Total Charges                 -0.198546
# Total Revenue                 -0.223003
# Total Long Distance Charges   -0.223756
# Number of Referrals           -0.286540
# Tenure in Months              -0.352861
# Name: Churn_Flag, dtype: float64

# %%
# Plot Correlation Matrix Heatmap

plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, fmt=".2f")
plt.title("Correlation Matrix Heatmap — Churn Likelihood Drivers", fontsize=14, weight='bold')
plt.show()

# %% [markdown]
# *The correlation analysis indicates that higher monthly charges and refund activities are key churn drivers, whereas tenure length and total revenue are protective factors against churn. This suggests that customer retention strategies should prioritize value perception and billing accuracy, while rewarding long-tenure customers to strengthen loyalty.*

# %% [markdown]
# ## 3. Initial Data Preparation

# %%
# Handle Churn-related missing values
# If there is no churn category, the customer is 'Active'
# If there is no churn reason, the reason is 'Not Applicable'

df['Churn Category'] = df['Churn Category'].fillna('Active')
df['Churn Reason'] = df['Churn Reason'].fillna('Not Applicable')

# %%
# Verify cleaning

print("Remaining Nulls:", df.isnull().sum().sum())
# Out:
# Remaining Nulls: 20501

# %%
# Drop unique identifiers that aren't useful for prediction

df = df.drop(columns=['Customer ID','Gender','Married','Number of Dependents','City','Zip Code','Latitude','Longitude','Offer','Multiple Lines','Phone Service','Streaming TV','Streaming Movies','Streaming Music','Unlimited Data','Paperless Billing','Payment Method','Total Refunds','Total Extra Data Charges','Total Long Distance Charges'])

# %%
# Create a binary target variable for analysis
# 1 = Churned, 0 = Stayed/Joined

df['Churn_Binary'] = df['Customer Status'].apply(lambda x: 1 if x == 'Churned' else 0)

print("Churn Distribution:")
print(df['Churn_Binary'].value_counts(normalize=True))
# Out:
# Churn Distribution:
# Churn_Binary
# 0    0.73463
# 1    0.26537
# Name: proportion, dtype: float64

# %%
# Setting 2 decimal place for Total Revenue column

df['Total Revenue'] = df['Total Revenue'].round(2)

# %%
# Setting 2 decimal place for Total Revenue column

df['Total Charges'] = df['Total Charges'].round(2)

# %% [markdown]
# ## 4. Initiation of Random Forest Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report, f1_score

# %%
# Handle Churn-related missing values and create binary target

df['Churn Category'] = df['Churn Category'].fillna('Active')
df['Customer Status'] = df['Customer Status'].apply(lambda x: 'Stayed_or_Joined' if x in ['Stayed', 'Joined'] else x)
df['Churn_Binary'] = df['Customer Status'].apply(lambda x: 1 if x == 'Churned' else 0)

# %%
# Encode the multi-class target variable

le = LabelEncoder()
df["Churn Category Encoded"] = le.fit_transform(df["Churn Category"])

# %%
# FEATURE SELECTION & PREPROCESSING

# New, enhanced feature set based on correlation and domain knowledge

NUMERICAL_FEATURES = [
    'Tenure in Months',
    'Monthly Charge',
    'Total Charges',
    'Total Revenue',
    'Number of Referrals'
]

CATEGORICAL_FEATURES = [
    'Contract',
    'Internet Service',
    'Internet Type',
    'Online Security',
    'Premium Tech Support'
]

# %%
# This ensures that any missing values in the chosen numerical features are removed.

df_processed = df.dropna(subset=NUMERICAL_FEATURES)

# %%
# Define preprocessor to handle numerical and categorical features
# Numerical features are left as is for tree-based model
# Categorical features are One-Hot Encoded

preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', NUMERICAL_FEATURES),
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), CATEGORICAL_FEATURES)
    ],
    remainder='drop'
)

# %%
# Define X (features) and y (target) using the enhanced feature list

X = df_processed[NUMERICAL_FEATURES + CATEGORICAL_FEATURES]
y = df_processed["Churn Category Encoded"]

# %%
# Train/Test Split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y)

# %%
# 4.0 Applying Random Forest with Pipeline

# Create the Random Forest model within a pipeline

model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(
        n_estimators=200,
        max_depth=5,
        random_state=42,
        class_weight='balanced' # Added to help with target imbalance
    ))
])

# %%
# Train the model
model_pipeline.fit(X_train, y_train)

# Predict and Evaluate
y_pred = model_pipeline.predict(X_test)

# %%
print("--- Model Performance with Enhanced Features ---")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print(f"Macro Average F1-Score: {f1_score(y_test, y_pred, average='macro'):.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred, zero_division=0))
# Out:
# --- Model Performance with Enhanced Features ---
# Accuracy: 0.5809
# Macro Average F1-Score: 0.2474
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.71      0.81      1294
#            1       0.06      0.06      0.06        79
#            2       0.34      0.36      0.35       210
#            3       0.07      0.15      0.10        80
#            4       0.04      0.18      0.06        45
#            5       0.09      0.15      0.11        53
#
#     accuracy                           0.58      1761
#    macro avg       0.26      0.27      0.25      1761
# weighted avg       0.74      0.58      0.65      1761

# %%
#Reverse transform predictions back to labels

predicted_categories = le.inverse_transform(y_pred)
# Display label distribution in predictions for insight
print("\nPredicted Category Distribution (Top 5):\n", pd.Series(predicted_categories).value_counts().head())
# Out:
# Predicted Category Distribution (Top 5):
#  Active             979
# Other              222
# Competitor         220
# Dissatisfaction    170
# Price               90
# Name: count, dtype: int64

# %%
# Feature Importance Analysis (post-training)

print("\n--- Feature Importance ---")
# Out:
# --- Feature Importance ---

# %%
# Get feature names after One-Hot Encoding
feature_names = (
    NUMERICAL_FEATURES + 
    list(model_pipeline['preprocessor'].named_transformers_['cat'].get_feature_names_out(CATEGORICAL_FEATURES))
)

# Get feature importances from the classifier
importances = model_pipeline['classifier'].feature_importances_
feature_importances = pd.Series(importances, index=feature_names).sort_values(ascending=False).head(10)

# %%
# Plot feature importance 

plt.figure(figsize=(12, 6))
sns.barplot(
    x=feature_importances.values, 
    y=feature_importances.index, 
    hue=feature_importances.index, # <-- ADD THIS: Assign the y-variable to hue
    palette='viridis',
    legend=False                   # <-- ADD THIS: Suppress the redundant legend
)
plt.title('Top 10 Feature Importance for Churn Category Prediction')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.show()

print(feature_importances)
# Out:
# Contract_Month-to-Month    0.175386
# Number of Referrals        0.130940
# Contract_Two Year          0.106905
# Total Charges              0.093671
# Tenure in Months           0.090929
# Monthly Charge             0.087050
# Total Revenue              0.084088
# Online Security_No         0.044499
# Contract_One Year          0.026387
# Premium Tech Support_No    0.025380
# dtype: float64

# %% [markdown]
# ## 5. Initiation of Dummy Classifier Baseline

# %%
from sklearn.dummy import DummyClassifier # ADDED: Import DummyClassifier

# Baseline 1: Stratified (Random Guessing)
dummy_stratified = DummyClassifier(strategy='stratified', random_state=42)

# Dummy classifiers do not need feature transformation, but we fit them on the target variable
dummy_stratified.fit(X_train, y_train)
dummy_pred_stratified = dummy_stratified.predict(X_test)

# %%
print("\n--- Model Performance: Baseline (Stratified) ---")
print(f"Accuracy: {accuracy_score(y_test, dummy_pred_stratified):.4f}")
print(f"Macro Average F1-Score: {f1_score(y_test, dummy_pred_stratified, average='macro', zero_division=0):.4f}")
print("\nClassification Report:\n", classification_report(y_test, dummy_pred_stratified, zero_division=0))
# Out:
# --- Model Performance: Baseline (Stratified) ---
# Accuracy: 0.5542
# Macro Average F1-Score: 0.1612
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73      1294
#            1       0.01      0.01      0.01        79
#            2       0.12      0.12      0.12       210
#            3       0.00      0.00      0.00        80
#            4       0.06      0.07      0.06        45
#            5       0.04      0.04      0.04        53
#
#     accuracy                           0.55      1761
#    macro avg       0.16      0.16      0.16      1761
# weighted avg       0.56      0.55      0.56      1761

# %%
# 5.2 Baseline 2: Most Frequent (Majority Class Guessing)

dummy_most_frequent = DummyClassifier(strategy='most_frequent')
dummy_most_frequent.fit(X_train, y_train)
dummy_pred_most_frequent = dummy_most_frequent.predict(X_test)

# %%
print("\n--- Model Performance: Baseline (Most Frequent) ---")
print(f"Accuracy: {accuracy_score(y_test, dummy_pred_most_frequent):.4f}")
print(f"Macro Average F1-Score: {f1_score(y_test, dummy_pred_most_frequent, average='macro', zero_division=0):.4f}")
print("\nClassification Report:\n", classification_report(y_test, dummy_pred_most_frequent, zero_division=0))
# Out:
# --- Model Performance: Baseline (Most Frequent) ---
# Accuracy: 0.7348
# Macro Average F1-Score: 0.1412
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      1.00      0.85      1294
#            1       0.00      0.00      0.00        79
#            2       0.00      0.00      0.00       210
#            3       0.00      0.00      0.00        80
#            4       0.00      0.00      0.00        45
#            5       0.00      0.00      0.00        53
#
#     accuracy                           0.73      1761
#    macro avg       0.12      0.17      0.14      1761
# weighted avg       0.54      0.73      0.62      1761

# %%
# Get feature names after One-Hot Encoding
feature_names = (
    NUMERICAL_FEATURES + 
    list(model_pipeline['preprocessor'].named_transformers_['cat'].get_feature_names_out(CATEGORICAL_FEATURES)))

# %%
# Get feature importances from the classifier

importances = model_pipeline['classifier'].feature_importances_
feature_importances = pd.Series(importances, index=feature_names).sort_values(ascending=False).head(10)

# %%
# Plot feature importance 

plt.figure(figsize=(12, 6))
sns.barplot(
    x=feature_importances.values, 
    y=feature_importances.index, 
    hue=feature_importances.index, # <--(Assign y-variable to hue)
    palette='viridis',
    legend=False                   # <--(Optional, but removes the redundant legend)
)
plt.title('Top 10 Feature Importance for Churn Category Prediction')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.show()

print(feature_importances)
# Out:
# Contract_Month-to-Month    0.175386
# Number of Referrals        0.130940
# Contract_Two Year          0.106905
# Total Charges              0.093671
# Tenure in Months           0.090929
# Monthly Charge             0.087050
# Total Revenue              0.084088
# Online Security_No         0.044499
# Contract_One Year          0.026387
# Premium Tech Support_No    0.025380
# dtype: float64

# %%
# Bivariate Analysis Churn vs Numerical Features

num_features = ['Age', 'Tenure in Months', 'Avg Monthly Long Distance Charges',
                'Avg Monthly GB Download', 'Monthly Charge', 'Total Charges']
 
for col in num_features:
    plt.figure(figsize=(7,4))
 
sns.boxplot(
    x='Customer Status', 
    y=col, 
    data=df, 
    hue='Customer Status', 
    palette='Set2',
    legend=False 
)
# Out:
# <Axes: xlabel='Customer Status', ylabel='Total Charges'>

# %%
df.head()
# Out:
#    Age  Number of Referrals  Tenure in Months  \
# 0   37                    2                 9
# 1   46                    0                 9
# 2   50                    0                 4
# 3   78                    1                13
# 4   75                    3                 3
#
#    Avg Monthly Long Distance Charges Internet Service Internet Type  \
# 0                              42.39              Yes         Cable
# 1                              10.69              Yes         Cable
# 2                              33.65              Yes   Fiber Optic
# 3                              27.82              Yes   Fiber Optic
# 4                               7.38              Yes   Fiber Optic
#
#    Avg Monthly GB Download Online Security Online Backup  \
# 0                     16.0              No           Yes
# 1                     10.0              No            No
# 2                     30.0              No            No
# 3                      4.0              No           Yes
# 4                     11.0              No            No
#
#   Device Protection Plan  ...        Contract Monthly Charge  Total Charges  \
# 0                     No  ...        One Year           65.6         593.30
# 1                     No  ...  Month-to-Month           -4.0         542.40
# 2                    Yes  ...  Month-to-Month           73.9         280.85
# 3                    Yes  ...  Month-to-Month           98.0        1237.85
# 4                     No  ...  Month-to-Month           83.9         267.40
#
#    Total Revenue   Customer Status   Churn Category  \
# 0         974.81  Stayed_or_Joined           Active
# 1         610.28  Stayed_or_Joined           Active
# 2         415.45           Churned       Competitor
# 3        1599.51           Churned  Dissatisfaction
# 4         289.54           Churned  Dissatisfaction
#
#                     Churn Reason Churn_Flag  Churn_Binary  \
# 0                 Not Applicable          0             0
# 1                 Not Applicable          0             0
# 2  Competitor had better devices          1             1
# 3        Product dissatisfaction          1             1
# 4            Network reliability          1             1
#
#    Churn Category Encoded
# 0                       0
# 1                       0
# 2                       2
# 3                       3
# 4                       3
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 6. Initiation of SMOTE (Synthetic Minority Over-sampling Technique)

# %% [markdown]
# ### To correct class imbalance classification

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\user\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (2.1.3)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.15.3)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (3.5.0)

# %%
import pandas as pd
from imblearn.over_sampling import SMOTE

# Use imblearn's Pipeline to correctly integrate the sampling step
from imblearn.pipeline import Pipeline as ImbPipeline 
from sklearn.ensemble import RandomForestClassifier
from sklearn.compose import ColumnTransformer

# %%
smote_sampler = SMOTE(sampling_strategy='not majority', random_state=42, k_neighbors=3)

preprocessor = model_pipeline['preprocessor']

smote_pipeline = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('smote', smote_sampler), # SMOTE is inserted here and applies ONLY to the training data
    ('classifier', RandomForestClassifier(
        n_estimators=200,
        max_depth=5,
        random_state=42,
        # To keep 'balanced' to further weight the minority classes
        class_weight='balanced' 
    ))
])

# %%
# Train the model (using your existing split data)
smote_pipeline.fit(X_train, y_train)

# Predict and evaluate
y_pred_smote = smote_pipeline.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder # Assuming 'le' is still available

print("--- Model Performance with SMOTE and Enhanced Features ---")
print(f"Accuracy: {accuracy_score(y_test, y_pred_smote):.4f}")
print(f"Macro Average F1-Score: {f1_score(y_test, y_pred_smote, average='macro', zero_division=0):.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred_smote, zero_division=0))

# Reverse transform predictions back to labels for insight
predicted_categories = le.inverse_transform(y_pred_smote)
print("\nPredicted Category Distribution (Top 5):\n", pd.Series(predicted_categories).value_counts().head())
# Out:
# --- Model Performance with SMOTE and Enhanced Features ---
# Accuracy: 0.6576
# Macro Average F1-Score: 0.2547
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85      1294
#            1       0.06      0.03      0.04        79
#            2       0.37      0.32      0.34       210
#            3       0.09      0.25      0.13        80
#            4       0.03      0.04      0.03        45
#            5       0.13      0.13      0.13        53
#
#     accuracy                           0.66      1761
#    macro avg       0.26      0.27      0.25      1761
# weighted avg       0.71      0.66      0.68      1761
#
#
# Predicted Category Distribution (Top 5):
#  Active             1197
# Dissatisfaction     222
# Competitor          180
# Other                76
# Price                53
# Name: count, dtype: int64

# %% [markdown]
# ## 7. Initiation of Hyperparameter Tuning

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.compose import ColumnTransformer

# %%
# Re-define the preprocessor for use in the new pipeline
# (This step is necessary if the existing preprocessor was part of a non-imb-Pipeline)
preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', NUMERICAL_FEATURES),
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), CATEGORICAL_FEATURES)
    ],
    remainder='drop'
)

# %%
# Define the SMOTE Sampler and Classifier

smote_sampler = SMOTE(sampling_strategy='not majority', random_state=42)
rf_classifier = RandomForestClassifier(random_state=42, class_weight='balanced')

# %%
# Build the complete pipeline: Preprocessing -> SMOTE -> Classifier
pipeline = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('smote', smote_sampler),
    ('classifier', rf_classifier)
])

# %%
#Tuning parameters for the Random Forest and SMOTE

param_grid = {
    # Random Forest Hyperparameters
    'classifier__n_estimators': [100, 200, 300, 500], # Number of trees in the forest
    'classifier__max_depth': [5, 10, 15, 20, None], # Maximum depth of the tree
    'classifier__min_samples_split': [2, 5, 10], # Minimum number of samples required to split an internal node
    'classifier__min_samples_leaf': [1, 2, 4], # Minimum number of samples required to be at a leaf node
    'smote__k_neighbors': [3, 5, 7] # SMOTE Hyperparameters # Increasing k_neighbors can sometimes improve the quality of synthetic sample
}

# %%
# Perform Randomized Search (Tuning)

rf_random_search = RandomizedSearchCV(
    estimator=pipeline, 
    param_distributions=param_grid, 
    n_iter=20, 
    cv=3, # Use 3-fold cross-validation
    scoring='f1_macro', 
    verbose=2, 
    random_state=42,
    n_jobs=-1 # Use all available cores for faster execution
)

# %%
# Fit the Randomized Search to the training data

print("Starting Randomized Search Cross-Validation...")
# Out:
# Starting Randomized Search Cross-Validation...

# %%
rf_random_search.fit(X_train, y_train) # Commented out fitting as X_train/y_train are external
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('num',
#                                                                                'passthrough',
#                                                                                ['Tenure '
#                                                                                 'in '
#                                                                                 'Months',
#                                                                                 'Monthly '
#                                                                                 'Charge',
#                                                                                 'Total '
#                                                                                 'Charges',
#                                                                                 'Total '
#                                                                                 'Revenue',
#                                                                                 'Number '
#                                                                                 'of '
#                                                                                 'Referrals']),
#                                                                               ('cat',
#                                                                                OneHotEncoder(handle_unknown='ignore',
#                                                                                              sparse_output=False),
#                                                                                ['Contract',
#                                                                                 'Internet '
#                                                                                 'Service',
#                                                                                 'Internet '
#                                                                                 'Type',
#                                                                                 'Online '
#                                                                                 'Securit...
#                                               RandomForestClassifier(class_weight='balanced',
#                                                                      random_state=42))]),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'classifier__max_depth': [5, 10, 15, 20,
#                                                                   None],
#                                         'classifier__min_samples_leaf': [1, 2,
#                                                                          4],
#                                         'classifier__min_samples_split': [2, 5,
#                                                                           10],
#                                         'classifier__n_estimators': [100, 200,
#                                                                      300, 500],
#                                         'smote__k_neighbors': [3, 5, 7]},
#                    random_state=42, scoring='f1_macro', verbose=2)

# %%
print("\n--- Best Hyperparameters Found ---")
# Out:
# --- Best Hyperparameters Found ---

# %%
print(rf_random_search.best_params_)
# Out:
# {'smote__k_neighbors': 7, 'classifier__n_estimators': 300, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 2, 'classifier__max_depth': 15}

# %%
print(f"\n--- Best Macro F1 Score Achieved: {rf_random_search.best_score_:.4f} ---")
# Out:
# --- Best Macro F1 Score Achieved: 0.2578 ---

# %%
best_rf_model = rf_random_search.best_estimator_
y_pred_tuned = best_rf_model.predict(X_test)

# %%
# Final evaluation report

print("\n--- Model Performance: Tuned RF + SMOTE ---")
print(f"Accuracy: {accuracy_score(y_test, y_pred_tuned):.4f}")
print(f"Macro Average F1-Score: {f1_score(y_test, y_pred_tuned, average='macro', zero_division=0):.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred_tuned, zero_division=0))
# Out:
# --- Model Performance: Tuned RF + SMOTE ---
# Accuracy: 0.6837
# Macro Average F1-Score: 0.2741
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1294
#            1       0.10      0.10      0.10        79
#            2       0.35      0.36      0.36       210
#            3       0.10      0.12      0.11        80
#            4       0.11      0.13      0.12        45
#            5       0.11      0.09      0.10        53
#
#     accuracy                           0.68      1761
#    macro avg       0.27      0.28      0.27      1761
# weighted avg       0.70      0.68      0.69      1761

# %%
# Display label distribution in predictions for insight

predicted_categories = le.inverse_transform(y_pred_tuned)
print("\nPredicted Category Distribution (Top 5):\n", pd.Series(predicted_categories).value_counts().head())
# Out:
# Predicted Category Distribution (Top 5):
#  Active             1253
# Competitor          218
# Dissatisfaction     105
# Attitude             83
# Other                56
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Initiation of XG Boost Model

# %%
# 8.0 XG Boost Model

# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\user\anaconda3\lib\site-packages (3.1.2)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from xgboost) (1.15.3)

# %%
from imblearn.over_sampling import SMOTE
import numpy as np
from imblearn.pipeline import Pipeline as ImbPipeline
import xgboost as xgb # Import XGBoost

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', NUMERICAL_FEATURES),
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), CATEGORICAL_FEATURES)
    ],
    remainder='drop'
)

# %%
# Define the XGBoost Pipeline and Parameter Grid

xgb_classifier = xgb.XGBClassifier(
    objective='multi:softmax', 
    eval_metric='mlogloss', 
    random_state=42,
    num_class=len(np.unique(y_train)) 
) 

smote_sampler = SMOTE(sampling_strategy='not majority', random_state=42)

# %%
# Build the complete pipeline

pipeline_xgb = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('smote', smote_sampler),
    ('classifier', xgb_classifier)
])

# %%
# Define the parameter grid for XGBoost Tuning

param_grid_xgb = {
    # XGBoost Hyperparameters (tuned using the 'classifier__' prefix)
    'classifier__n_estimators': [100, 200, 300], 
    'classifier__max_depth': [3, 5, 7, 9], # Controls complexity
    'classifier__learning_rate': [0.01, 0.1, 0.2], # Step size shrinkage
    'classifier__gamma': [0, 0.1, 1], # Minimum loss reduction required to make a further partition
    'classifier__lambda': [0.1, 1, 10], # L2 regularization term on weights
    'classifier__alpha': [0.1, 1, 10], # L1 regularization term on weights
    
    # SMOTE Hyperparameters
    'smote__k_neighbors': [3, 5] 
}

# %%
print("Starting Randomized Search Cross-Validation for XGBoost...")

xgb_random_search = RandomizedSearchCV(
    estimator=pipeline_xgb, 
    param_distributions=param_grid_xgb, 
    n_iter=30, # Increase iterations for a deeper search
    cv=3, 
    scoring='f1_macro', # CRITICAL: Maximize reliability across all classes
    verbose=2, 
    random_state=42,
    n_jobs=-1
)
# Out:
# Starting Randomized Search Cross-Validation for XGBoost...

# %%
xgb_random_search.fit(X_train, y_train) # Commented out fitting as X_train/y_train are external
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('num',
#                                                                                'passthrough',
#                                                                                ['Tenure '
#                                                                                 'in '
#                                                                                 'Months',
#                                                                                 'Monthly '
#                                                                                 'Charge',
#                                                                                 'Total '
#                                                                                 'Charges',
#                                                                                 'Total '
#                                                                                 'Revenue',
#                                                                                 'Number '
#                                                                                 'of '
#                                                                                 'Referrals']),
#                                                                               ('cat',
#                                                                                OneHotEncoder(handle_unknown='ignore',
#                                                                                              sparse_output=False),
#                                                                                ['Contract',
#                                                                                 'Internet '
#                                                                                 'Service',
#                                                                                 'Internet '
#                                                                                 'Type',
#                                                                                 'Online '
#                                                                                 'Securit...
#                                                             n_jobs=None,
#                                                             num_class=6, ...))]),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions={'classifier__alpha': [0.1, 1, 10],
#                                         'classifier__gamma': [0, 0.1, 1],
#                                         'classifier__lambda': [0.1, 1, 10],
#                                         'classifier__learning_rate': [0.01, 0.1,
#                                                                       0.2],
#                                         'classifier__max_depth': [3, 5, 7, 9],
#                                         'classifier__n_estimators': [100, 200,
#                                                                      300],
#                                         'smote__k_neighbors': [3, 5]},
#                    random_state=42, scoring='f1_macro', verbose=2)

# %%
# Evaluation of Best XGBoost Model

print("\n--- Best XGBoost Hyperparameters Found ---")
print(xgb_random_search.best_params_)
# Out:
# --- Best XGBoost Hyperparameters Found ---
# {'smote__k_neighbors': 5, 'classifier__n_estimators': 100, 'classifier__max_depth': 5, 'classifier__learning_rate': 0.1, 'classifier__lambda': 0.1, 'classifier__gamma': 0.1, 'classifier__alpha': 0.1}

# %%
best_xgb_model = xgb_random_search.best_estimator_
y_pred_xgb_tuned = best_xgb_model.predict(X_test)

# %%
print("\n--- Model Performance: Tuned XGBoost + SMOTE ---")
# Out:
# --- Model Performance: Tuned XGBoost + SMOTE ---

# %%
print(f"Macro Average F1-Score: {f1_score(y_test, y_pred_xgb_tuned, average='macro', zero_division=0):.4f}")
# Out:
# Macro Average F1-Score: 0.2904

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred_xgb_tuned, zero_division=0))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87      1294
#            1       0.14      0.23      0.18        79
#            2       0.33      0.26      0.29       210
#            3       0.14      0.17      0.16        80
#            4       0.08      0.13      0.10        45
#            5       0.16      0.15      0.16        53
#
#     accuracy                           0.68      1761
#    macro avg       0.29      0.30      0.29      1761
# weighted avg       0.71      0.68      0.69      1761

# %%
df.head()
# Out:
#    Age  Number of Referrals  Tenure in Months  \
# 0   37                    2                 9
# 1   46                    0                 9
# 2   50                    0                 4
# 3   78                    1                13
# 4   75                    3                 3
#
#    Avg Monthly Long Distance Charges Internet Service Internet Type  \
# 0                              42.39              Yes         Cable
# 1                              10.69              Yes         Cable
# 2                              33.65              Yes   Fiber Optic
# 3                              27.82              Yes   Fiber Optic
# 4                               7.38              Yes   Fiber Optic
#
#    Avg Monthly GB Download Online Security Online Backup  \
# 0                     16.0              No           Yes
# 1                     10.0              No            No
# 2                     30.0              No            No
# 3                      4.0              No           Yes
# 4                     11.0              No            No
#
#   Device Protection Plan  ...        Contract Monthly Charge  Total Charges  \
# 0                     No  ...        One Year           65.6         593.30
# 1                     No  ...  Month-to-Month           -4.0         542.40
# 2                    Yes  ...  Month-to-Month           73.9         280.85
# 3                    Yes  ...  Month-to-Month           98.0        1237.85
# 4                     No  ...  Month-to-Month           83.9         267.40
#
#    Total Revenue   Customer Status   Churn Category  \
# 0         974.81  Stayed_or_Joined           Active
# 1         610.28  Stayed_or_Joined           Active
# 2         415.45           Churned       Competitor
# 3        1599.51           Churned  Dissatisfaction
# 4         289.54           Churned  Dissatisfaction
#
#                     Churn Reason Churn_Flag  Churn_Binary  \
# 0                 Not Applicable          0             0
# 1                 Not Applicable          0             0
# 2  Competitor had better devices          1             1
# 3        Product dissatisfaction          1             1
# 4            Network reliability          1             1
#
#    Churn Category Encoded
# 0                       0
# 1                       0
# 2                       2
# 3                       3
# 4                       3
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 9. Using SMOTE on All Minority Classes (Full SMOTE) in the Pipeline

# %% [markdown]
# #### To explicitly balance all minority classes up to the number of samples in the largest class (Class 0 - 'Active') to maximize the training signal for all categories.

# %%
# The goal is to oversample all classes to the size of the majority class (Class 0).

target_counts = y_train.value_counts()
n_samples = target_counts.max()

# Create the sampling dictionary: {class_label: new_target_count}

sampling_strategy_dict = {
    class_label: n_samples
    for class_label in target_counts.index
}

# %%
# The initial SMOTE used 'not majority', but defining the dictionary
# ensures we upsample all minority classes to the size of the majority class (0).
# This is a common and aggressive balancing technique for multi-class problems.
# The keys of this dictionary (0 to 5) correspond to the Churn Category Encoded labels.
# 0: Active, 1: Attitude, 2: Competitor, 3: Dissatisfaction, 4: Other, 5: Price

print("Target Sampling Strategy (Oversampling all to the majority class size):")
print(sampling_strategy_dict)
# Out:
# Target Sampling Strategy (Oversampling all to the majority class size):
# {0: 3880, 2: 3880, 3: 3880, 1: 3880, 5: 3880, 4: 3880}

# %%
# Redefine Preprocessor (Same as before)

NUMERICAL_FEATURES = [
    'Tenure in Months',
    'Monthly Charge',
    'Total Charges',
    'Total Revenue',
    'Number of Referrals'
]
CATEGORICAL_FEATURES = [
    'Contract',
    'Internet Service',
    'Internet Type',
    'Online Security',
    'Premium Tech Support'
]

preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', NUMERICAL_FEATURES),
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), CATEGORICAL_FEATURES)
    ],
    remainder='drop'
)

# %%
# Build XGBoost Pipeline with Explicit SMOTE Strategy ---
# Use the new, explicit sampling_strategy_dict
smote_sampler = SMOTE(
    sampling_strategy=sampling_strategy_dict,
    random_state=42
)

xgb_classifier = xgb.XGBClassifier(
    objective='multi:softmax', 
    eval_metric='mlogloss', 
    random_state=42,
    num_class=len(np.unique(y_train)),
    
) 

pipeline_xgb_balanced = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('smote', smote_sampler),
    ('classifier', xgb_classifier)
])

# %%
param_grid_xgb_balanced = {
    # XGBoost Hyperparameters: Adjust n_estimators since SMOTE creates a much larger dataset.
    'classifier__n_estimators': [100, 200], # Fewer estimators may be faster/sufficient
    'classifier__max_depth': [5, 7, 9], 
    'classifier__learning_rate': [0.05, 0.1], 
    'classifier__gamma': [0.1, 1],
    'classifier__lambda': [0.1, 1],
    'classifier__alpha': [0.1, 1],
    
    # SMOTE Hyperparameters: No need to tune sampling_strategy since we set it.
    'smote__k_neighbors': [3, 5] 
}

# %%
xgb_random_search_balanced = RandomizedSearchCV(
    estimator=pipeline_xgb_balanced, 
    param_distributions=param_grid_xgb_balanced, 
    n_iter=20, # Reduced n_iter for a quicker example, you can increase this
    cv=3, 
    scoring='f1_macro', 
    verbose=1, 
    random_state=42,
    n_jobs=-1
)

# %%
xgb_random_search_balanced.fit(X_train, y_train) 
best_xgb_model_balanced = xgb_random_search_balanced.best_estimator_
y_pred_balanced = best_xgb_model_balanced.predict(X_test)

print("\n--- Tuned XGBoost + Full SMOTE Evaluation ---")
print(f"Macro F1-Score: {f1_score(y_test, y_pred_balanced, average='macro', zero_division=0):.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred_balanced, zero_division=0))
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
#
# --- Tuned XGBoost + Full SMOTE Evaluation ---
# Macro F1-Score: 0.2902
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      1294
#            1       0.13      0.15      0.14        79
#            2       0.35      0.32      0.33       210
#            3       0.14      0.20      0.16        80
#            4       0.08      0.16      0.11        45
#            5       0.13      0.13      0.13        53
#
#     accuracy                           0.68      1761
#    macro avg       0.29      0.30      0.29      1761
# weighted avg       0.71      0.68      0.69      1761
